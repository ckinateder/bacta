# %% [markdown]
# # Volatility Strategy
#
# Trying this: https://www.reddit.com/r/Trading/comments/ujy1x8/volatility_trading_algorithm_for_shortterm/.

# %%
from datetime import datetime, timedelta
import logging

from alpaca.data.timeframe import TimeFrame, TimeFrameUnit
import pandas as pd
from talib import ATR, EMA, RSI

from examples.data import (
    download_bars,
    separate_bars_by_symbol,
    split_multi_index_bars_train_test,
)

from bacta.backtester import EventBacktester, Order, Position
from bacta.utilities import dash
from bacta.utilities.logger import get_logger, set_log_level

set_log_level(logging.DEBUG)

# %%
class VolatilityStrategy(EventBacktester):
    """
    Backtester that uses the Keltner Channel to make decisions.
    """

    def __init__(self, active_symbols, cash, **kwargs):
        super().__init__(active_symbols, cash, **kwargs)
        self.short_ema_period = 21
        self.long_ema_period = 200
        self.rsi_period = 14

    def precompute_step(self, bars: pd.DataFrame):
        """
        Preload the indicators for the backtest.
        """
        split_bars = separate_bars_by_symbol(bars)

    def update_step(self, bars: pd.DataFrame, index: pd.Timestamp):
        """
        Update the state of the backtester.
        """
        split_bars = separate_bars_by_symbol(bars)
        

    def generate_orders(self, bar: pd.DataFrame, index: pd.Timestamp) -> list[Order]:
        """
        Make a decision based on the prices.
        """
        close_prices = bar.loc[:, "close"]
        # short ema is 21, long ema is 200
        # rsi is 14
        # if rsi is > 75 and short ema is > long ema, then short
        # if rsi is < 25 and short ema is < long ema, then long
        orders = []
        
        return orders

# %%
symbols = ["DTE", "DUK"]

bars = download_bars(
    symbols,
    start_date=datetime(2024, 1, 1),
    end_date=datetime(2025, 7, 31),
    timeframe=TimeFrame(1, TimeFrameUnit.Hour)
)
# split the bars into train and test
train_bars, test_bars = split_multi_index_bars_train_test(
    bars, split_ratio=0.9)

# create the backtester
backtester = VolatilityStrategy(
    symbols,
    cash=3000,
    allow_short=True,
    min_cash_balance=100,
    max_short_value=3000,
    min_trade_value=1,
    market_hours_only=True,
    transaction_cost=0.000,
    transaction_cost_type="percentage",
)

# preload the train bars
backtester.load_train_bars(train_bars)

# run_backtest the backtest
backtester.run_backtest(test_bars)

# plot the order and state history
#print(dash("order history"))
#print(backtester.get_history())
#print(dash("state history"))
#print(backtester.get_state_history())
# Out:
# [2025-08-11 17:40:23][DEBUG] Loading data/DTEDUK_2024-01-01_2025-07-31_1Hour.pkl
# [2025-08-11 17:40:23][DEBUG] Initializing backtester with active symbols: ['DTE', 'DUK'], cash: 10000, allow_short: True, min_cash_balance: 100, max_short_value: 2000, min_trade_value: 1, market_hours_only: True
# [2025-08-11 17:40:23][INFO] Train bars have been previously loaded. Concatenating with test bars...
# [2025-08-11 17:40:23][INFO] Running backtest over 16572 bars from 2025-04-06 18:00:00-04:00 to 2025-07-30 19:00:00-04:00...
# [2025-08-11 17:40:23][DEBUG] Placing LONG 3.2579 DTE @ $122.780 (2025-04-09 10:00:00-04:00)
# [2025-08-11 17:40:23][DEBUG] Placing LONG 3.5952 DUK @ $111.260 (2025-04-09 10:00:00-04:00)
# [2025-08-11 17:40:23][DEBUG] Placing LONG 3.2433 DTE @ $123.330 (2025-04-09 11:00:00-04:00)
# [2025-08-11 17:40:24][DEBUG] Skipping SHORT 0.0 DTE @ $133.750 (max short value limit) (2025-04-17 13:00:00-04:00)
# [2025-08-11 17:40:24][DEBUG] Skipping SHORT 0.0 DUK @ $122.180 (max short value limit) (2025-04-17 13:00:00-04:00)
# [2025-08-11 17:40:24][DEBUG] Skipping SHORT 0.0 DTE @ $133.810 (max short value limit) (2025-04-17 14:00:00-04:00)
# [2025-08-11 17:40:25][DEBUG] Placing LONG 3.3585 DUK @ $119.100 (2025-04-21 16:00:00-04:00)
# [2025-08-11 17:40:25][DEBUG] Placing adjusted SHORT 1.5058 DTE @ $134.400 (2025-04-22 10:00:00-04:00)
# [2025-08-11 17:40:26][DEBUG] Skipping SHORT 0.0 DTE @ $134.900 (max short value limit) (2025-04-22 11:00:00-04:00)
# [2025-08-11 17:40:26][DEBUG] Placing adjusted SHORT 1.5664 DUK @ $121.600 (2025-04-22 11:00:00-04:00)
# [2025-08-11 17:40:26][DEBUG] Skipping SHORT 0.0 DTE @ $134.190 (max short value limit) (2025-04-22 12:00:00-04:00)
# [2025-08-11 17:40:26][DEBUG] Skipping SHORT 0.0 DTE @ $134.700 (max short value limit) (2025-04-22 15:00:00-04:00)
# [2025-08-11 17:40:26][DEBUG] Skipping SHORT 0.0 DTE @ $134.700 (max short value limit) (2025-04-22 16:00:00-04:00)
# [2025-08-11 17:40:26][DEBUG] Skipping SHORT 0.0 DTE @ $136.160 (max short value limit) (2025-04-24 12:00:00-04:00)
# [2025-08-11 17:40:26][DEBUG] Skipping SHORT 0.0 DTE @ $136.360 (max short value limit) (2025-04-24 14:00:00-04:00)
# [2025-08-11 17:40:27][DEBUG] Skipping SHORT 0.0 DTE @ $135.240 (max short value limit) (2025-04-29 10:00:00-04:00)
# [2025-08-11 17:40:27][DEBUG] Placing adjusted SHORT 0.1529 DUK @ $120.480 (2025-04-29 10:00:00-04:00)
# [2025-08-11 17:40:27][DEBUG] Skipping SHORT 0.0 DTE @ $135.300 (max short value limit) (2025-04-29 11:00:00-04:00)
# [2025-08-11 17:40:27][DEBUG] Placing adjusted SHORT 0.0401 DUK @ $120.190 (2025-04-29 11:00:00-04:00)
# [2025-08-11 17:40:27][DEBUG] Skipping SHORT 0.0 DTE @ $135.980 (max short value limit) (2025-04-29 12:00:00-04:00)
# [2025-08-11 17:40:27][DEBUG] Skipping SHORT 0.0 DUK @ $120.230 (max short value limit) (2025-04-29 12:00:00-04:00)
# [2025-08-11 17:40:27][DEBUG] Skipping SHORT 0.0 DTE @ $136.530 (max short value limit) (2025-04-29 13:00:00-04:00)
# [2025-08-11 17:40:27][DEBUG] Skipping SHORT 0.0 DUK @ $120.740 (max short value limit) (2025-04-29 13:00:00-04:00)
# [2025-08-11 17:40:27][DEBUG] Skipping SHORT 0.0 DTE @ $136.300 (max short value limit) (2025-04-29 14:00:00-04:00)
# [2025-08-11 17:40:27][DEBUG] Skipping SHORT 0.0 DUK @ $120.600 (max short value limit) (2025-04-29 15:00:00-04:00)
# [2025-08-11 17:40:27][DEBUG] Skipping SHORT 0.0 DUK @ $120.620 (max short value limit) (2025-04-29 16:00:00-04:00)
# [2025-08-11 17:40:27][DEBUG] Skipping SHORT 0.0 DTE @ $136.570 (max short value limit) (2025-05-06 10:00:00-04:00)
# [2025-08-11 17:40:27][DEBUG] Skipping SHORT 0.0 DUK @ $121.970 (max short value limit) (2025-05-06 10:00:00-04:00)
# [2025-08-11 17:40:27][DEBUG] Skipping SHORT 0.0 DTE @ $136.580 (max short value limit) (2025-05-06 11:00:00-04:00)
# [2025-08-11 17:40:27][DEBUG] Skipping SHORT 0.0 DUK @ $122.470 (max short value limit) (2025-05-06 11:00:00-04:00)
# [2025-08-11 17:40:27][DEBUG] Skipping SHORT 0.0 DTE @ $136.520 (max short value limit) (2025-05-06 12:00:00-04:00)
# [2025-08-11 17:40:27][DEBUG] Skipping SHORT 0.0 DUK @ $122.350 (max short value limit) (2025-05-06 12:00:00-04:00)
# [2025-08-11 17:40:27][DEBUG] Skipping SHORT 0.0 DTE @ $136.770 (max short value limit) (2025-05-06 13:00:00-04:00)
# [2025-08-11 17:40:27][DEBUG] Skipping SHORT 0.0 DUK @ $122.800 (max short value limit) (2025-05-06 13:00:00-04:00)
# [2025-08-11 17:40:27][DEBUG] Skipping SHORT 0.0 DTE @ $137.210 (max short value limit) (2025-05-06 14:00:00-04:00)
# [2025-08-11 17:40:27][DEBUG] Skipping SHORT 0.0 DUK @ $122.780 (max short value limit) (2025-05-06 14:00:00-04:00)
# [2025-08-11 17:40:28][DEBUG] Skipping SHORT 0.0 DTE @ $137.740 (max short value limit) (2025-05-07 11:00:00-04:00)
# [2025-08-11 17:40:28][DEBUG] Skipping SHORT 0.0 DTE @ $138.100 (max short value limit) (2025-05-07 12:00:00-04:00)
# [2025-08-11 17:40:28][DEBUG] Placing LONG 3.3619 DUK @ $118.980 (2025-05-08 15:00:00-04:00)
# [2025-08-11 17:40:28][DEBUG] Placing LONG 3.3591 DUK @ $119.080 (2025-05-08 16:00:00-04:00)
# [2025-08-11 17:40:28][DEBUG] Placing LONG 3.3701 DUK @ $118.690 (2025-05-09 10:00:00-04:00)
# [2025-08-11 17:40:28][DEBUG] Placing LONG 3.3659 DUK @ $118.840 (2025-05-09 11:00:00-04:00)
# [2025-08-11 17:40:28][DEBUG] Placing LONG 2.9782 DTE @ $134.310 (2025-05-09 12:00:00-04:00)
# [2025-08-11 17:40:28][DEBUG] Placing LONG 3.373 DUK @ $118.590 (2025-05-09 12:00:00-04:00)
# [2025-08-11 17:40:28][DEBUG] Placing LONG 3.0344 DTE @ $131.820 (2025-05-12 10:00:00-04:00)
# [2025-08-11 17:40:28][DEBUG] Placing LONG 3.4501 DUK @ $115.940 (2025-05-12 10:00:00-04:00)
# [2025-08-11 17:40:28][DEBUG] Placing LONG 3.0572 DTE @ $130.840 (2025-05-12 11:00:00-04:00)
# [2025-08-11 17:40:28][DEBUG] Placing LONG 3.4704 DUK @ $115.260 (2025-05-12 11:00:00-04:00)
# [2025-08-11 17:40:28][DEBUG] Placing LONG 3.0319 DTE @ $131.930 (2025-05-12 12:00:00-04:00)
# [2025-08-11 17:40:28][DEBUG] Placing LONG 3.4575 DUK @ $115.690 (2025-05-12 12:00:00-04:00)
# [2025-08-11 17:40:39][DEBUG] Placing SHORT 2.9983 DTE @ $133.410 (2025-07-10 12:00:00-04:00)
# [2025-08-11 17:40:39][DEBUG] Placing SHORT 2.9933 DTE @ $133.630 (2025-07-10 13:00:00-04:00)
# [2025-08-11 17:40:39][DEBUG] Placing SHORT 3.3844 DUK @ $118.190 (2025-07-10 13:00:00-04:00)
# [2025-08-11 17:40:39][DEBUG] Placing SHORT 2.9967 DTE @ $133.480 (2025-07-10 14:00:00-04:00)
# [2025-08-11 17:40:39][DEBUG] Placing SHORT 3.3855 DUK @ $118.150 (2025-07-10 14:00:00-04:00)
# [2025-08-11 17:40:39][DEBUG] Placing SHORT 2.9938 DTE @ $133.610 (2025-07-10 15:00:00-04:00)
# [2025-08-11 17:40:39][DEBUG] Placing SHORT 3.385 DUK @ $118.170 (2025-07-10 15:00:00-04:00)
# [2025-08-11 17:40:39][DEBUG] Placing SHORT 2.9927 DTE @ $133.660 (2025-07-10 16:00:00-04:00)
# [2025-08-11 17:40:39][DEBUG] Placing SHORT 3.385 DUK @ $118.170 (2025-07-10 16:00:00-04:00)
# [2025-08-11 17:40:40][DEBUG] Placing SHORT 2.9698 DTE @ $134.690 (2025-07-14 10:00:00-04:00)
# [2025-08-11 17:40:40][DEBUG] Placing SHORT 2.9811 DTE @ $134.180 (2025-07-16 15:00:00-04:00)
# [2025-08-11 17:40:40][DEBUG] Placing adjusted SHORT 2.6575 DTE @ $134.230 (2025-07-16 16:00:00-04:00)
# [2025-08-11 17:40:40][DEBUG] Skipping SHORT 0.0 DTE @ $134.450 (max short value limit) (2025-07-17 10:00:00-04:00)
# [2025-08-11 17:40:40][DEBUG] Skipping SHORT 0.0 DTE @ $134.775 (max short value limit) (2025-07-17 11:00:00-04:00)
# [2025-08-11 17:40:40][DEBUG] Skipping SHORT 0.0 DTE @ $135.160 (max short value limit) (2025-07-17 14:00:00-04:00)
# [2025-08-11 17:40:40][DEBUG] Skipping SHORT 0.0 DTE @ $136.090 (max short value limit) (2025-07-18 10:00:00-04:00)
# [2025-08-11 17:40:40][DEBUG] Skipping SHORT 0.0 DTE @ $136.620 (max short value limit) (2025-07-18 11:00:00-04:00)
# [2025-08-11 17:40:40][DEBUG] Skipping SHORT 0.0 DTE @ $136.610 (max short value limit) (2025-07-18 12:00:00-04:00)
# [2025-08-11 17:40:40][DEBUG] Skipping SHORT 0.0 DTE @ $136.765 (max short value limit) (2025-07-18 13:00:00-04:00)
# [2025-08-11 17:40:40][DEBUG] Placing SHORT 3.3696 DUK @ $118.710 (2025-07-18 13:00:00-04:00)
# [2025-08-11 17:40:40][DEBUG] Skipping SHORT 0.0 DTE @ $136.660 (max short value limit) (2025-07-18 14:00:00-04:00)
# [2025-08-11 17:40:40][DEBUG] Skipping SHORT 0.0 DTE @ $137.290 (max short value limit) (2025-07-18 15:00:00-04:00)
# [2025-08-11 17:40:40][DEBUG] Skipping SHORT 0.0 DTE @ $137.980 (max short value limit) (2025-07-18 16:00:00-04:00)
# [2025-08-11 17:40:41][DEBUG] Placing SHORT 3.347 DUK @ $119.510 (2025-07-21 10:00:00-04:00)
# [2025-08-11 17:40:41][DEBUG] Skipping SHORT 0.0 DTE @ $138.480 (max short value limit) (2025-07-21 11:00:00-04:00)
# [2025-08-11 17:40:41][DEBUG] Placing SHORT 3.3326 DUK @ $120.025 (2025-07-21 11:00:00-04:00)
# [2025-08-11 17:40:41][DEBUG] Skipping SHORT 0.0 DTE @ $138.535 (max short value limit) (2025-07-21 12:00:00-04:00)
# [2025-08-11 17:40:41][DEBUG] Placing SHORT 3.3331 DUK @ $120.010 (2025-07-21 12:00:00-04:00)
# [2025-08-11 17:40:41][DEBUG] Placing SHORT 3.3357 DUK @ $119.915 (2025-07-21 13:00:00-04:00)
# [2025-08-11 17:40:41][DEBUG] Placing SHORT 3.3372 DUK @ $119.860 (2025-07-21 14:00:00-04:00)
# [2025-08-11 17:40:41][DEBUG] Placing SHORT 3.3378 DUK @ $119.840 (2025-07-21 15:00:00-04:00)
# [2025-08-11 17:40:41][DEBUG] Placing SHORT 3.3381 DUK @ $119.830 (2025-07-21 16:00:00-04:00)
# [2025-08-11 17:40:41][DEBUG] Skipping SHORT 0.0 DTE @ $139.110 (max short value limit) (2025-07-22 10:00:00-04:00)
# [2025-08-11 17:40:41][DEBUG] Skipping SHORT 0.0 DTE @ $139.010 (max short value limit) (2025-07-22 11:00:00-04:00)
# [2025-08-11 17:40:41][DEBUG] Skipping SHORT 0.0 DTE @ $139.095 (max short value limit) (2025-07-22 12:00:00-04:00)
# [2025-08-11 17:40:41][DEBUG] Skipping SHORT 0.0 DTE @ $139.455 (max short value limit) (2025-07-22 13:00:00-04:00)
# [2025-08-11 17:40:41][DEBUG] Skipping SHORT 0.0 DTE @ $139.630 (max short value limit) (2025-07-22 14:00:00-04:00)
# [2025-08-11 17:40:41][DEBUG] Skipping SHORT 0.0 DTE @ $139.520 (max short value limit) (2025-07-22 15:00:00-04:00)
# [2025-08-11 17:40:41][DEBUG] Skipping SHORT 0.0 DTE @ $139.550 (max short value limit) (2025-07-22 16:00:00-04:00)
# [2025-08-11 17:40:42][DEBUG] Skipping SHORT 0.0 DTE @ $139.210 (max short value limit) (2025-07-24 12:00:00-04:00)
# [2025-08-11 17:40:42][DEBUG] Placing LONG 3.3809 DUK @ $118.310 (2025-07-28 11:00:00-04:00)
# [2025-08-11 17:40:42][DEBUG] Placing LONG 3.3858 DUK @ $118.140 (2025-07-28 12:00:00-04:00)
# [2025-08-11 17:40:42][DEBUG] Placing LONG 3.3895 DUK @ $118.010 (2025-07-28 13:00:00-04:00)
# [2025-08-11 17:40:42][DEBUG] Placing LONG 3.3906 DUK @ $117.974 (2025-07-28 14:00:00-04:00)
# [2025-08-11 17:40:42][DEBUG] Placing LONG 3.4008 DUK @ $117.620 (2025-07-28 15:00:00-04:00)
# [2025-08-11 17:40:42][DEBUG] Placing LONG 3.399 DUK @ $117.680 (2025-07-28 16:00:00-04:00)
# [2025-08-11 17:40:43][DEBUG] Placing SHORT 3.3031 DUK @ $121.100 (2025-07-30 14:00:00-04:00)
# [2025-08-11 17:40:43][INFO] Closing positions at 2025-07-30 16:00:00-04:00...
# - order history ----------------------------------------------------------------
#                           symbol  position     price  quantity
# 2025-04-09 10:00:00-04:00    DTE         1  122.7800    3.2579
# 2025-04-09 10:00:00-04:00    DUK         1  111.2600    3.5952
# 2025-04-09 11:00:00-04:00    DTE         1  123.3300    3.2433
# 2025-04-09 11:00:00-04:00    DUK         1  111.8100    3.5775
# 2025-04-14 10:00:00-04:00    DTE        -1  132.5900    3.0168
# ...                          ...       ...       ...       ...
# 2025-07-28 15:00:00-04:00    DUK         1  117.6200    3.4008
# 2025-07-28 16:00:00-04:00    DUK         1  117.6800    3.3990
# 2025-07-30 14:00:00-04:00    DUK        -1  121.1000    3.3031
# 2025-07-30 16:00:00-04:00    DTE         1  135.0005   14.8997
# 2025-07-30 16:00:00-04:00    DUK        -1  119.5600   51.1930
#
# [152 rows x 4 columns]
# - state history ----------------------------------------------------------------
#                                    cash  portfolio_value      DTE      DUK
# 0                          10000.000000     10000.000000   0.0000   0.0000
# 2025-04-06 18:00:00-04:00  10000.000000     10000.000000   0.0000   0.0000
# 2025-04-06 19:00:00-04:00  10000.000000     10000.000000   0.0000   0.0000
# 2025-04-06 20:00:00-04:00  10000.000000     10000.000000   0.0000   0.0000
# 2025-04-06 21:00:00-04:00  10000.000000     10000.000000   0.0000   0.0000
# ...                                 ...              ...      ...      ...
# 2025-07-30 12:00:00-04:00   6356.779503     10898.041243 -14.8997  54.4961
# 2025-07-30 13:00:00-04:00   6356.779503     10906.869808 -14.8997  54.4961
# 2025-07-30 14:00:00-04:00   6756.784913     10914.484273 -14.8997  51.1930
# 2025-07-30 15:00:00-04:00   6756.784913     10911.426668 -14.8997  51.1930
# 2025-07-30 16:00:00-04:00  10865.953043     10865.953043   0.0000   0.0000
#
# [2760 rows x 4 columns]

# %%
# plot the performance
print(dash("performance"))
print(backtester.pretty_format_performance())
# Out:
# - performance ------------------------------------------------------------------
# Backtest Performance:
# - Return on Investment: 8.66%
# - vs. Buy and Hold Return: 3.15%
# - Sharpe Ratio: 0.40
# - Max Drawdown Percentage: 2.98%
#
# - Start Portfolio Value: $10000.00
# - End Portfolio Value: $10865.95
# - Min Portfolio Value: $9849.56
# - Max Portfolio Value: $10914.48
# - Min Cash Balance: $0.01
# - Max Cash Balance: $12240.17
# - Win Rate: 90.00%
#
# - Number of Orders: 152
# - Number of Winning Trades: 135
# - Number of Losing Trades: 15
# - Avg Trade Return: 2.69%
# - Largest Win: 7.99% ($29.59)
# - Largest Loss: -1.73% ($-6.66)
# - Max Consecutive Wins: 7
# - Max Consecutive Losses: 1
#
# - Trading Period Start: 2025-04-06 18:00:00-04:00
# - Trading Period End: 2025-07-30 16:00:00-04:00
# - Trading Period Length: 114 days 22:00:00
# - Time in Market: 97.61%

# %%
# Plot the results
print("plotting...")
backtester.plot_performance_analysis(
    title="_".join(symbols) + " EMA RSI Strategy Performance", show_plot=False)
# Out:
# plotting...

# %%
backtester.plot_trade_history(title="_".join(
    symbols) + " EMA RSI Strategy Trades", show_plot=False)

# %%
backtester.plot_equity_curve(
    title="_".join(symbols) + " EMA RSI Strategy Equity Curve", show_plot=False
)
